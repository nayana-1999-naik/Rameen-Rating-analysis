# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('ramen-ratings.csv')

# %%
df
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df.shape
# Out:
# (2580, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
df.describe()
# Out:
#           Review #
# count  2580.000000
# mean   1290.500000
# std     744.926171
# min       1.000000
# 25%     645.750000
# 50%    1290.500000
# 75%    1935.250000
# max    2580.000000

# %%
df.Variety.unique().tolist()
# Out:
# ["T's Restaurant Tantanmen ",
#  'Noodles Spicy Hot Sesame Spicy Hot Sesame Guan-miao Noodles',
#  'Cup Noodles Chicken Vegetable',
#  'GGE Ramen Snack Tomato Flavor',
#  'Singapore Curry',
#  'Kimchi song Song Ramen',
#  'Spice Deli Tantan Men With Cilantro',
#  'Nabeyaki Kitsune Udon',
#  'Hokkaido Soy Sauce Ramen',
#  'The Original Spicy Stir-Fried Noodles',
#  'Creamy tom Yum Kung Flavour',
#  'Yokohama Tonkotsu Shoyu',
#  'Mr. Bibim Stir-Fried Kimchi Flavor',
#  'Deka Buto Kimchi Pork Flavor',
#  'Demae Ramen Bar Noodle Aka Tonkotsu Flavour Instant Noodle',
#  'Mushroom Flavour Instant Noodles',
#  'Mario Masala Noodles',
#  'Tokyo Shoyu Ramen',
#  'Mi Hai Cua',
#  'Premium Gomtang',
#  'Cup Noodles Laksa Flavour',
#  'Beef Ramen',
#  'Creamy Soup With Crushed Noodles Hot & Sour Fish Flavor',
#  'Sapporo Miso Ramen',
#  'Hot Garlic Instant Noodles',
#  'Song Song Kimchi Big Bowl',
#  'Instant Noodles Beef In Light Soup Flavour',
#  'Hakata Ramen Noodle White Tonkotsu',
# ...

# %%
df.Variety.unique()
# Out:
# array(["T's Restaurant Tantanmen ",
#        'Noodles Spicy Hot Sesame Spicy Hot Sesame Guan-miao Noodles',
#        'Cup Noodles Chicken Vegetable', ...,
#        'Hu Tiu Nam Vang ["Phnom Penh" style] Asian Style Instant\xa0Rice\xa0Noodles',
#        'Oriental Style Instant Noodles', 'Tom Yum Chili Flavor'],
#       dtype=object)

# %%
df.drop(columns = 'Variety',inplace = True)

# %%
df.Stars.unique()
# Out:
# array(['3.75', '1', '2.25', '2.75', '4.75', '4', '0.25', '2.5', '5',
#        '4.25', '4.5', '3.5', 'Unrated', '1.5', '3.25', '2', '0', '3',
#        '0.5', '4.00', '5.0', '3.50', '3.8', '4.3', '2.3', '5.00', '3.3',
#        '4.0', '3.00', '1.75', '3.0', '4.50', '0.75', '1.25', '1.1', '2.1',
#        '0.9', '3.1', '4.125', '3.125', '2.125', '2.9', '0.1', '2.8',
#        '3.7', '3.4', '3.6', '2.85', '3.2', '3.65', '1.8'], dtype=object)

# %%
df[df.Stars=='Unrated']
# Out:
#      Review #          Brand Style      Country    Stars Top Ten
# 32       2548         Ottogi  Pack  South Korea  Unrated     NaN
# 122      2458  Samyang Foods  Pack  South Korea  Unrated     NaN
# 993      1587       Mi E-Zee  Pack     Malaysia  Unrated     NaN

# %%
df['Stars']=df.Stars.replace({'Unrated':np.nan})

# %%
df[df.Stars=='Unrated']
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Style, Country, Stars, Top Ten]
# Index: []

# %%
df.drop(columns = 'Top Ten',inplace = True)

# %%
df.Stars =  df.Stars.astype('float')

# %%
df.dtypes
# Out:
# Review #      int64
# Brand        object
# Style        object
# Country      object
# Stars       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Review #    0
# Brand       0
# Style       2
# Country     0
# Stars       3
# dtype: int64

# %%
df.head()
# Out:
#    Review #           Brand Style Country  Stars
# 0      2580       New Touch   Cup   Japan   3.75
# 1      2579        Just Way  Pack  Taiwan   1.00
# 2      2578          Nissin   Cup     USA   2.25
# 3      2577         Wei Lih  Pack  Taiwan   2.75
# 4      2576  Ching's Secret  Pack   India   3.75

# %%
df.Stars.fillna(df.Stars.mean(),inplace = True)

# %%
df.Style.fillna(df.Style.mode()[0],inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Style, Country, Stars]
# Index: []

# %%
df[['Review #', 'Stars']].corr()
# Out:
#           Review #     Stars
# Review #  1.000000  0.243242
# Stars     0.243242  1.000000

# %%
cat_cols = df.describe(include = 'object').columns.to_list()

# %%
cat_cols
# Out:
# ['Brand', 'Style', 'Country']

# %%
for  i in cat_cols:
    print(df[i].value_counts())
    print(df[i].unique())
    print(df[i].nunique())
    print(df.groupby(i)['Stars'].mean())
    print('---'*10)
# Out:
# Brand
# Nissin           381
# Nongshim          98
# Maruchan          76
# Mama              71
# Paldo             66
#                 ...
# Golden Wonder      1
# Peyang             1
# Sanrio             1
# China Best         1
# Westbrae           1
# Name: count, Length: 355, dtype: int64
# ['New Touch' 'Just Way' 'Nissin' 'Wei Lih' "Ching's Secret"
#  'Samyang Foods' 'Acecook' 'Ikeda Shoku' "Ripe'n'Dry" 'KOKA' 'Tao Kae Noi'
#  'Yamachan' 'Nongshim' 'TRDP' 'Binh Tay' 'Paldo' 'Jackpot Teriyaki'
#  'Yum-Mie' 'MyKuali' 'Ottogi' 'Sichuan Guangyou' 'Lipton' 'Lele'
#  'Fujiwara' 'Uni-President' 'Maruchan' 'Prima' 'Sokensha' 'Takamori'
#  'Guava Story' 'Samurai Ramen' 'Ogasawara' 'Pringles' "Mom's Dry Noodle"
#  'Maggi' 'Indomie' 'Happy Cook' 'The Ramen Rater Select' 'TTL' 'E-Zee'
#  'Kiki Noodle' 'Tokyo Noodle' 'GGE' 'Myojo' 'Sau Tao' 'Wang' 'Daifuku'
#  'Master Kong' "World O' Noodle" 'Kang Shi Fu' 'Mum Ngon' 'Fashion Food'
# ...

# %%
df[df.describe().columns].corr()['Stars']
# Out:
# Review #    0.243242
# Stars       1.000000
# Name: Stars, dtype: float64

# %%
sns.boxplot(x=df.Stars)
# Out:
# <Axes: xlabel='Stars'>

# %%
sns.displot(df.Stars,kde=True)

# %%
np.log(max( df.Stars) - df.Stars + 1)
# Out:
# 0       0.810930
# 1       1.609438
# 2       1.321756
# 3       1.178655
# 4       0.810930
#           ...
# 2575    0.916291
# 2576    1.609438
# 2577    1.386294
# 2578    1.386294
# 2579    1.704748
# Name: Stars, Length: 2580, dtype: float64

# %%
sns.displot(np.log(max( df.Stars) - df.Stars + 1),kde=True)

# %%
sns.displot(np.cbrt(max(df.Stars) - df.Stars + 1), kde=True)

# %%
sns.displot(np.sqrt(max( df.Stars) - df.Stars + 1),kde=True)

# %%
df1 = df.copy()

# %%
df['Stars'] = np.sqrt(max( df.Stars) - df.Stars + 1)

# %%
df.head()
# Out:
#    Review #           Brand Style Country     Stars
# 0      2580       New Touch   Cup   Japan  1.500000
# 1      2579        Just Way  Pack  Taiwan  2.236068
# 2      2578          Nissin   Cup     USA  1.936492
# 3      2577         Wei Lih  Pack  Taiwan  1.802776
# 4      2576  Ching's Secret  Pack   India  1.500000

# %%
df.drop(columns = 'Brand',inplace=True)

# %%
plt.hist(df.Stars)
# Out:
# (array([450., 135., 542., 359., 511., 266., 160.,  65.,  40.,  52.]),
#  array([1.        , 1.14494897, 1.28989795, 1.43484692, 1.5797959 ,
#         1.72474487, 1.86969385, 2.01464282, 2.15959179, 2.30454077,
#         2.44948974]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x='Review #',y='Stars',data=df,hue='Stars')
# Out:
# <Axes: xlabel='Review #', ylabel='Stars'>

# %%
df.rename(columns = {'Review #':'Review'},inplace = True)

# %% [markdown]
# ## Encoding

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

df['Style'] = encoder.fit_transform(df['Style'])

# %%
df['Country'] = encoder.fit_transform(df['Country'])

# %%
df1['Style'] = encoder.fit_transform(df1['Style'])

# %%
df1['Country'] = encoder.fit_transform(df1['Country'])

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## Spliting into dependent and independent variable

# %%
X=df.drop('Stars',axis=1)   
y = df.Stars

# %%
print(X.shape,y.shape)
# Out:
# (2580, 3) (2580,)

# %% [markdown]
# ## Spliting testing and training

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,train_size=.8,random_state =0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (2064, 3) (516, 3) (2064,) (516,)

# %% [markdown]
# ## Linear Regression

# %%
df.head()
# Out:
#    Review  Style  Country     Stars
# 0    2580      4       18  1.500000
# 1    2579      5       32  2.236068
# 2    2578      4       35  1.936492
# 3    2577      5       32  1.802776
# 4    2576      5       16  1.500000

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.06669975267479711

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.07960714409877712

# %% [markdown]
# ## Decession Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()

# %%
dt
# Out:
# DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 1.0

# %%
r2_score(y_test,y_test_pred)
# Out:
# -0.46077044422712055

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=900, max_depth=3)

# %%
rf
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=900)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=900)

# %%
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.1644675246859172

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.16720369041678085

# %% [markdown]
# ## OLS(Ordinary Least Squares)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df.columns
# Out:
# Index(['Review', 'Style', 'Country', 'Stars'], dtype='object')

# %%
ols1 = smf.ols(formula="Stars ~ Review  + Style + Country",data = df).fit()

# %%
ols1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     64.43
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           3.61e-40
# Time:                        10:58:25   Log-Likelihood:                -637.23
# No. Observations:                2580   AIC:                             1282.
# Df Residuals:                    2576   BIC:                             1306.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6456      0.027     62.008      0.000       1.594       1.698
# ...

# %%
ols2 = smf.ols(formula="Stars ~ Review  +  Country",data = df).fit()

# %%
ols2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     96.69
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           3.24e-41
# Time:                        10:58:32   Log-Likelihood:                -637.23
# No. Observations:                2580   AIC:                             1280.
# Df Residuals:                    2577   BIC:                             1298.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6457      0.021     77.488      0.000       1.604       1.687
# ...

# %%
ols3 = smf.ols(formula="Stars ~ Review  ",data = df).fit()

# %%
ols3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     193.4
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           1.85e-42
# Time:                        10:58:41   Log-Likelihood:                -637.23
# No. Observations:                2580   AIC:                             1278.
# Df Residuals:                    2578   BIC:                             1290.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6444      0.012    134.731      0.000       1.620       1.668
# ...

# %% [markdown]
# ## Before Transforming Data

# %%
X1=df1.drop('Stars',axis=1)   
y1 = df1.Stars

# %%
X_train,X_test,y_train,y_test = train_test_split(X1,y1,test_size=.2,train_size=.8,random_state = 0)

# %%
df1
# Out:
#       Review #  Style  Country  Stars
# 0         2580      4       18   3.75
# 1         2579      5       32   1.00
# 2         2578      4       35   2.25
# 3         2577      5       32   2.75
# 4         2576      5       16   3.75
# ...        ...    ...      ...    ...
# 2575         5      1       37   3.50
# 2576         4      5       33   1.00
# 2577         3      5       33   2.00
# 2578         2      5       33   2.00
# 2579         1      5       35   0.50
#
# [2580 rows x 4 columns]

# %%
df1.drop(columns='Brand',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 df1.drop(columns='Brand',inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
from sklearn.linear_model import LinearRegression
lr1= LinearRegression()
lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr1.predict(X_train)
y_test_pred = lr1.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.056250016036757944

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.06830631574755908

# %% [markdown]
# ## Decision Tree

# %%
dt
# Out:
# DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 1.0

# %%
r2_score(y_test,y_test_pred)
# Out:
# -0.5581401434528002

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestRegressor(n_estimators=500, max_depth=3)

# %%
rf
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=500)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=500)

# %%
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.16441558994359506

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.15357910887579884

# %% [markdown]
# ## OLS(Ordinary Least Squares)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df1.rename(columns={'Review #':'Review'},inplace = True)

# %%
df1.columns
# Out:
# Index(['Review', 'Style', 'Country', 'Stars'], dtype='object')

# %%
ols1 = smf.ols(formula="Stars ~ Review + Style + Country",data = df1).fit()

# %%
ols1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     54.02
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           7.38e-34
# Time:                        00:07:30   Log-Likelihood:                -3619.4
# No. Observations:                2580   AIC:                             7247.
# Df Residuals:                    2576   BIC:                             7270.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2099      0.084     38.073      0.000       3.045       3.375
# ...

# %%
ols2 = smf.ols(formula="Stars ~ Review + Style ",data = df1).fit()

# %%
ols2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     81.06
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           7.26e-35
# Time:                        00:07:32   Log-Likelihood:                -3619.4
# No. Observations:                2580   AIC:                             7245.
# Df Residuals:                    2577   BIC:                             7262.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2159      0.064     50.042      0.000       3.090       3.342
# ...

# %%
ols3 = smf.ols(formula="Stars ~ Review  ",data = df1).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Review' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[231], line 1
# ----> 1 ols3 = smf.ols(formula="Stars ~ Review  ",data = df1).fit()
#
# ...

# %%
ols3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Stars   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     193.4
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           1.85e-42
# Time:                        11:00:01   Log-Likelihood:                -637.23
# No. Observations:                2580   AIC:                             1278.
# Df Residuals:                    2578   BIC:                             1290.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6444      0.012    134.731      0.000       1.620       1.668
# ...
